# %% [markdown]
# ## featuretools で特徴量作成

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import featuretools as ft
import featuretools.variable_types as vtypes
from boruta import BorutaPy

from sklearn.ensemble import RandomForestClassifier

import check_miss_value

# %% [markdown]
# ## 学習データ

# %%
# pickle ファイルから読み込み
train_pkl = pd.read_pickle('../001/train.pk1')

# %%
train_pkl.shape
# Out:
# (242150, 10)

# %%
# グレード(grade)、目的(purpose)は削除
train_pkl.drop(['grade', 'purpose'], axis=1, inplace=True)

# %%
train_pkl.head()
# Out:
#    id    loan_amnt  term  interest_rate  employment_length  credit_score  \
# 0   0   609.296068     3       8.421982                  0    714.061803
# 1   1  1183.266999     5      10.286776                 10    697.706701
# 2   2   695.783256     3      14.723425                  1    656.419357
# 3   3   738.392546     3      14.260708                  0    657.906852
# 4   4  1642.400654     5      25.217452                 10    662.972297
#
#    application_type  loan_status
# 0                 0            0
# 1                 0            1
# 2                 0            0
# 3                 0            0
# 4                 0            0

# %%
train_pk2 = train_pkl.copy()
train_pkl.shape
# Out:
# (242150, 8)

# %%
es = ft.EntitySet(id='feature')

# %%
es.entity_from_dataframe( 
    entity_id='feature_id',
    dataframe=train_pkl.drop(['id', 'loan_status'], axis=1),
    index='index',
    variable_types={}
)
# Out:
# C:\Users\owner\Anaconda3\lib\site-packages\featuretools\entityset\entity.py:609: UserWarning: index index not found in dataframe, creating new integer column
#   "integer column".format(index))
# Entityset: feature
#   Entities:
#     feature_id [Rows: 242150, Columns: 7]
#   Relationships:
#     No relationships

# %%
feature_matrix, features_dfs = ft.dfs(
    entityset=es,
    target_entity='feature_id',
    agg_primitives=['sum', 'mean', 'std', 'max', 'count', 'skew'],
    trans_primitives=['add_numeric', 'subtract_numeric', 'multiply_numeric', 'divide_numeric'],
    max_depth=1,
)
# Out:
# C:\Users\owner\Anaconda3\lib\site-packages\featuretools\synthesis\dfs.py:317: UnusedPrimitiveWarning: Some specified primitives were not used during DFS:
#   agg_primitives: ['count', 'max', 'mean', 'skew', 'std', 'sum']
# This may be caused by a using a value of max_depth that is too small, not setting interesting values, or it may indicate no compatible variable types for the primitive were found in the data.
#   warnings.warn(warning_msg, UnusedPrimitiveWarning)

# %%
feature_matrix.shape
# Out:
# (242150, 81)

# %%
feature_matrix.head()
# Out:
#          loan_amnt  term  interest_rate  employment_length  credit_score  \
# index
# 0       609.296068     3       8.421982                  0    714.061803
# 1      1183.266999     5      10.286776                 10    697.706701
# 2       695.783256     3      14.723425                  1    656.419357
# 3       738.392546     3      14.260708                  0    657.906852
# 4      1642.400654     5      25.217452                 10    662.972297
#
#        application_type  application_type + credit_score  \
# index
# 0                     0                       714.061803
# 1                     0                       697.706701
# 2                     0                       656.419357
# 3                     0                       657.906852
# 4                     0                       662.972297
#
#        application_type + employment_length  application_type + interest_rate  \
# index
# 0                                         0                          8.421982
# 1                                        10                         10.286776
# 2                                         1                         14.723425
# 3                                         0                         14.260708
# 4                                        10                         25.217452
#
#        application_type + loan_amnt  ...  credit_score - employment_length  \
# index                                ...
# 0                        609.296068  ...                        714.061803
# 1                       1183.266999  ...                        687.706701
# 2                        695.783256  ...                        655.419357
# 3                        738.392546  ...                        657.906852
# 4                       1642.400654  ...                        652.972297
#
#        credit_score - interest_rate  credit_score - loan_amnt  \
# index
# 0                        705.639821                104.765735
# 1                        687.419925               -485.560298
# 2                        641.695933                -39.363899
# 3                        643.646144                -80.485694
# 4                        637.754845               -979.428357
#
#        credit_score - term  employment_length - interest_rate  \
# index
# 0               711.061803                          -8.421982
# 1               692.706701                          -0.286776
# 2               653.419357                         -13.723425
# 3               654.906852                         -14.260708
# 4               657.972297                         -15.217452
#
#        employment_length - loan_amnt  employment_length - term  \
# index
# 0                        -609.296068                        -3
# 1                       -1173.266999                         5
# 2                        -694.783256                        -2
# 3                        -738.392546                        -3
# 4                       -1632.400654                         5
#
#        interest_rate - loan_amnt  interest_rate - term  loan_amnt - term
# index
# 0                    -600.874086              5.421982        606.296068
# 1                   -1172.980223              5.286776       1178.266999
# 2                    -681.059832             11.723425        692.783256
# 3                    -724.131838             11.260708        735.392546
# 4                   -1617.183202             20.217452       1637.400654
#
# [5 rows x 81 columns]

# %%
train_pkl = feature_matrix.copy()

# %%
train_pkl['loan_status'] = train_pk2['loan_status']
train_pkl['id'] = train_pk2[('id')]

# %%
train_pkl.shape
# Out:
# (242150, 83)

# %%
train_pkl.describe()
# Out:
# C:\Users\owner\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3942: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#            loan_amnt           term  interest_rate  employment_length  \
# count  242150.000000  242150.000000  242150.000000      242150.000000
# mean     1520.389009       3.431658      13.801496           6.672298
# std       830.250197       0.822794       4.588924           3.657411
# min       323.797279       3.000000       5.704849           0.000000
# 25%       761.954545       3.000000      10.876086           3.000000
# 50%      1212.680586       3.000000      13.543833           9.000000
# 75%      2152.213330       3.000000      17.172395          10.000000
# max      3851.867974       5.000000      27.980604          10.000000
#
#         credit_score  application_type  application_type + credit_score  \
# count  242150.000000     242150.000000                    242150.000000
# mean      683.575024          0.007359                       683.582383
# std        29.554795          0.085469                        29.556557
# min       655.424269          0.000000                       655.424269
# 25%       659.531106          0.000000                       659.535793
# 50%       678.672563          0.000000                       678.678756
# 75%       698.591960          0.000000                       698.595488
# max       808.551641          1.000000                       808.551641
#
#        application_type + employment_length  application_type + interest_rate  \
# count                         242150.000000                     242150.000000
# mean                               6.679657                         13.808855
# std                                3.656696                          4.590767
# min                                0.000000                          5.704849
# 25%                                3.000000                         10.881283
# 50%                                9.000000                         13.547887
# 75%                               10.000000                         17.176818
# max                               11.000000                         28.980604
#
#        application_type + loan_amnt  ...  credit_score - loan_amnt  \
# count                 242150.000000  ...             242150.000000
# mean                    1520.396369  ...               -836.813985
# std                      830.254507  ...                827.868342
# min                      323.797279  ...              -3175.687333
# 25%                      761.954545  ...              -1456.738754
# 50%                     1212.686834  ...               -543.566096
# 75%                     2152.223840  ...                -94.138528
# max                     3851.867974  ...                462.497412
#
#        credit_score - term  employment_length - interest_rate  \
# count        242150.000000                      242150.000000
# mean            680.143366                          -7.129197
# std              29.590202                           5.864958
# min             650.510945                         -27.528590
# 25%             656.161458                         -11.415029
# 50%             675.292875                          -6.997864
# 75%             695.267101                          -3.048240
# max             804.433596                           4.295151
#
#        employment_length - loan_amnt  employment_length - term  \
# count                  242150.000000             242150.000000
# mean                    -1513.716711                  3.240640
# std                       830.014131                  3.725264
# min                     -3851.867974                 -5.000000
# 25%                     -2145.168102                  0.000000
# 50%                     -1206.503023                  5.000000
# 75%                      -756.153564                  7.000000
# max                      -313.797279                  7.000000
#
#        interest_rate - loan_amnt  interest_rate - term  loan_amnt - term  \
# count              242150.000000         242150.000000     242150.000000
# mean                -1506.587514             10.369838       1516.957351
# std                   829.295029              4.269758        829.966347
# min                 -3839.018030              0.812533        320.797279
# 25%                 -2137.691382              7.722855        758.919295
# 50%                 -1198.974968             10.279170       1209.357969
# 75%                  -748.529252             12.980316       2148.261662
# max                  -316.593872             24.260526       3846.867974
#
#          loan_status            id
# count  242150.000000  242150.00000
# mean        0.174916  121074.50000
# std         0.379896   69902.82818
# min         0.000000       0.00000
# 25%         0.000000   60537.25000
# 50%         0.000000  121074.50000
# 75%         0.000000  181611.75000
# max         1.000000  242149.00000
#
# [8 rows x 83 columns]

# %%
train_pkl.isnull().sum()[train_pkl.isnull().sum() > 0]
# Out:
# application_type / employment_length    18851
# employment_length / application_type    18851
# dtype: int64

# %%
train_pkl.fillna(0, inplace=True)

# %%
train_pkl.isnull().sum()[train_pkl.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
train_pkl.describe()
# Out:
#            loan_amnt           term  interest_rate  employment_length  \
# count  242150.000000  242150.000000  242150.000000      242150.000000
# mean     1520.389009       3.431658      13.801496           6.672298
# std       830.250197       0.822794       4.588924           3.657411
# min       323.797279       3.000000       5.704849           0.000000
# 25%       761.954545       3.000000      10.876086           3.000000
# 50%      1212.680586       3.000000      13.543833           9.000000
# 75%      2152.213330       3.000000      17.172395          10.000000
# max      3851.867974       5.000000      27.980604          10.000000
#
#         credit_score  application_type  application_type + credit_score  \
# count  242150.000000     242150.000000                    242150.000000
# mean      683.575024          0.007359                       683.582383
# std        29.554795          0.085469                        29.556557
# min       655.424269          0.000000                       655.424269
# 25%       659.531106          0.000000                       659.535793
# 50%       678.672563          0.000000                       678.678756
# 75%       698.591960          0.000000                       698.595488
# max       808.551641          1.000000                       808.551641
#
#        application_type + employment_length  application_type + interest_rate  \
# count                         242150.000000                     242150.000000
# mean                               6.679657                         13.808855
# std                                3.656696                          4.590767
# min                                0.000000                          5.704849
# 25%                                3.000000                         10.881283
# 50%                                9.000000                         13.547887
# 75%                               10.000000                         17.176818
# max                               11.000000                         28.980604
#
#        application_type + loan_amnt  ...  credit_score - loan_amnt  \
# count                 242150.000000  ...             242150.000000
# mean                    1520.396369  ...               -836.813985
# std                      830.254507  ...                827.868342
# min                      323.797279  ...              -3175.687333
# 25%                      761.954545  ...              -1456.738754
# 50%                     1212.686834  ...               -543.566096
# 75%                     2152.223840  ...                -94.138528
# max                     3851.867974  ...                462.497412
#
#        credit_score - term  employment_length - interest_rate  \
# count        242150.000000                      242150.000000
# mean            680.143366                          -7.129197
# std              29.590202                           5.864958
# min             650.510945                         -27.528590
# 25%             656.161458                         -11.415029
# 50%             675.292875                          -6.997864
# 75%             695.267101                          -3.048240
# max             804.433596                           4.295151
#
#        employment_length - loan_amnt  employment_length - term  \
# count                  242150.000000             242150.000000
# mean                    -1513.716711                  3.240640
# std                       830.014131                  3.725264
# min                     -3851.867974                 -5.000000
# 25%                     -2145.168102                  0.000000
# 50%                     -1206.503023                  5.000000
# 75%                      -756.153564                  7.000000
# max                      -313.797279                  7.000000
#
#        interest_rate - loan_amnt  interest_rate - term  loan_amnt - term  \
# count              242150.000000         242150.000000     242150.000000
# mean                -1506.587514             10.369838       1516.957351
# std                   829.295029              4.269758        829.966347
# min                 -3839.018030              0.812533        320.797279
# 25%                 -2137.691382              7.722855        758.919295
# 50%                 -1198.974968             10.279170       1209.357969
# 75%                  -748.529252             12.980316       2148.261662
# max                  -316.593872             24.260526       3846.867974
#
#          loan_status            id
# count  242150.000000  242150.00000
# mean        0.174916  121074.50000
# std         0.379896   69902.82818
# min         0.000000       0.00000
# 25%         0.000000   60537.25000
# 50%         0.000000  121074.50000
# 75%         0.000000  181611.75000
# max         1.000000  242149.00000
#
# [8 rows x 83 columns]

# %%
train_pkl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242150 entries, 0 to 242149
# Data columns (total 83 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   loan_amnt                             242150 non-null  float64
#  1   term                                  242150 non-null  int16
#  2   interest_rate                         242150 non-null  float64
#  3   employment_length                     242150 non-null  int16
#  4   credit_score                          242150 non-null  float64
#  5   application_type                      242150 non-null  int8
#  6   application_type + credit_score       242150 non-null  float64
#  7   application_type + employment_length  242150 non-null  int16
#  8   application_type + interest_rate      242150 non-null  float64
#  9   application_type + loan_amnt          242150 non-null  float64
#  10  application_type + term               242150 non-null  int16
#  11  credit_score + employment_length      242150 non-null  float64
#  12  credit_score + interest_rate          242150 non-null  float64
#  13  credit_score + loan_amnt              242150 non-null  float64
#  14  credit_score + term                   242150 non-null  float64
#  15  employment_length + interest_rate     242150 non-null  float64
#  16  employment_length + loan_amnt         242150 non-null  float64
#  17  employment_length + term              242150 non-null  int16
#  18  interest_rate + loan_amnt             242150 non-null  float64
#  19  interest_rate + term                  242150 non-null  float64
#  20  loan_amnt + term                      242150 non-null  float64
#  21  application_type / credit_score       242150 non-null  float64
#  22  application_type / employment_length  242150 non-null  float64
#  23  application_type / interest_rate      242150 non-null  float64
#  24  application_type / loan_amnt          242150 non-null  float64
#  25  application_type / term               242150 non-null  float64
#  26  credit_score / application_type       242150 non-null  float64
#  27  credit_score / employment_length      242150 non-null  float64
#  28  credit_score / interest_rate          242150 non-null  float64
#  29  credit_score / loan_amnt              242150 non-null  float64
#  30  credit_score / term                   242150 non-null  float64
#  31  employment_length / application_type  242150 non-null  float64
#  32  employment_length / credit_score      242150 non-null  float64
#  33  employment_length / interest_rate     242150 non-null  float64
#  34  employment_length / loan_amnt         242150 non-null  float64
#  35  employment_length / term              242150 non-null  float64
#  36  interest_rate / application_type      242150 non-null  float64
#  37  interest_rate / credit_score          242150 non-null  float64
#  38  interest_rate / employment_length     242150 non-null  float64
#  39  interest_rate / loan_amnt             242150 non-null  float64
#  40  interest_rate / term                  242150 non-null  float64
#  41  loan_amnt / application_type          242150 non-null  float64
#  42  loan_amnt / credit_score              242150 non-null  float64
#  43  loan_amnt / employment_length         242150 non-null  float64
#  44  loan_amnt / interest_rate             242150 non-null  float64
#  45  loan_amnt / term                      242150 non-null  float64
#  46  term / application_type               242150 non-null  float64
#  47  term / credit_score                   242150 non-null  float64
#  48  term / employment_length              242150 non-null  float64
#  49  term / interest_rate                  242150 non-null  float64
#  50  term / loan_amnt                      242150 non-null  float64
#  51  application_type * credit_score       242150 non-null  float64
#  52  application_type * employment_length  242150 non-null  int16
#  53  application_type * interest_rate      242150 non-null  float64
#  54  application_type * loan_amnt          242150 non-null  float64
#  55  application_type * term               242150 non-null  int16
#  56  credit_score * employment_length      242150 non-null  float64
#  57  credit_score * interest_rate          242150 non-null  float64
#  58  credit_score * loan_amnt              242150 non-null  float64
#  59  credit_score * term                   242150 non-null  float64
#  60  employment_length * interest_rate     242150 non-null  float64
#  61  employment_length * loan_amnt         242150 non-null  float64
#  62  employment_length * term              242150 non-null  int16
#  63  interest_rate * loan_amnt             242150 non-null  float64
#  64  interest_rate * term                  242150 non-null  float64
#  65  loan_amnt * term                      242150 non-null  float64
#  66  application_type - credit_score       242150 non-null  float64
#  67  application_type - employment_length  242150 non-null  int16
#  68  application_type - interest_rate      242150 non-null  float64
#  69  application_type - loan_amnt          242150 non-null  float64
#  70  application_type - term               242150 non-null  int16
#  71  credit_score - employment_length      242150 non-null  float64
#  72  credit_score - interest_rate          242150 non-null  float64
#  73  credit_score - loan_amnt              242150 non-null  float64
#  74  credit_score - term                   242150 non-null  float64
#  75  employment_length - interest_rate     242150 non-null  float64
#  76  employment_length - loan_amnt         242150 non-null  float64
#  77  employment_length - term              242150 non-null  int16
#  78  interest_rate - loan_amnt             242150 non-null  float64
#  79  interest_rate - term                  242150 non-null  float64
#  80  loan_amnt - term                      242150 non-null  float64
#  81  loan_status                           242150 non-null  int8
#  82  id                                    242150 non-null  int64
# dtypes: float64(69), int16(11), int64(1), int8(2)
# memory usage: 136.7 MB

# %%
train_pkl.to_pickle('train.pk2')

# %%
train_pk3 = train_pkl.copy()
train_pk3.replace(np.inf, np.nan, inplace=True)

# %%
train_pk3.isnull().sum()[train_pk3.isnull().sum() > 0]
# Out:
# application_type / employment_length       522
# credit_score / application_type         240368
# credit_score / employment_length         19373
# employment_length / application_type    221517
# interest_rate / application_type        240368
# interest_rate / employment_length        19373
# loan_amnt / application_type            240368
# loan_amnt / employment_length            19373
# term / application_type                 240368
# term / employment_length                 19373
# dtype: int64

# %% [markdown]
# ## 検証データ

# %%
# pickle ファイルから読み込み
test_pkl = pd.read_pickle('../001/test.pk1')

# %%
test_pkl.shape
# Out:
# (26900, 9)

# %%
# グレード(grade)、目的(purpose)は削除
test_pkl.drop(['grade', 'purpose'], axis=1, inplace=True)

# %%
test_pkl.head()
# Out:
#        id    loan_amnt  term  interest_rate  employment_length  credit_score  \
# 0  242150  1161.830205     3      13.105362                 10    682.016083
# 1  242151  2257.465815     5      14.196200                 10    668.240313
# 2  242152  2182.137002     3       8.307772                 10    703.277694
# 3  242153   520.284912     3       6.956504                  7    731.138779
# 4  242154  2303.349549     3      11.658497                  6    698.368991
#
#    application_type
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
test_pk2 = test_pkl.copy()
test_pkl.shape, test_pk2.shape
# Out:
# ((26900, 7), (26900, 7))

# %%
es = ft.EntitySet(id='feature')

# %%
es.entity_from_dataframe( 
    entity_id='feature_id',
    dataframe=test_pkl.drop(['id'], axis=1),
    index='index',
    variable_types={}
)
# Out:
# C:\Users\owner\Anaconda3\lib\site-packages\featuretools\entityset\entity.py:609: UserWarning: index index not found in dataframe, creating new integer column
#   "integer column".format(index))
# Entityset: feature
#   Entities:
#     feature_id [Rows: 26900, Columns: 7]
#   Relationships:
#     No relationships

# %%
feature_matrix, features_dfs = ft.dfs(
    entityset=es,
    target_entity='feature_id',
    agg_primitives=['sum', 'mean', 'std', 'max', 'count', 'skew'],
    trans_primitives=['add_numeric', 'subtract_numeric', 'multiply_numeric', 'divide_numeric'],
    max_depth=1,
)
# Out:
# C:\Users\owner\Anaconda3\lib\site-packages\featuretools\synthesis\dfs.py:317: UnusedPrimitiveWarning: Some specified primitives were not used during DFS:
#   agg_primitives: ['count', 'max', 'mean', 'skew', 'std', 'sum']
# This may be caused by a using a value of max_depth that is too small, not setting interesting values, or it may indicate no compatible variable types for the primitive were found in the data.
#   warnings.warn(warning_msg, UnusedPrimitiveWarning)

# %%
feature_matrix.shape
# Out:
# (26900, 81)

# %%
feature_matrix.head()
# Out:
#          loan_amnt  term  interest_rate  employment_length  credit_score  \
# index
# 0      1161.830205     3      13.105362                 10    682.016083
# 1      2257.465815     5      14.196200                 10    668.240313
# 2      2182.137002     3       8.307772                 10    703.277694
# 3       520.284912     3       6.956504                  7    731.138779
# 4      2303.349549     3      11.658497                  6    698.368991
#
#        application_type  application_type + credit_score  \
# index
# 0                     0                       682.016083
# 1                     0                       668.240313
# 2                     0                       703.277694
# 3                     0                       731.138779
# 4                     0                       698.368991
#
#        application_type + employment_length  application_type + interest_rate  \
# index
# 0                                        10                         13.105362
# 1                                        10                         14.196200
# 2                                        10                          8.307772
# 3                                         7                          6.956504
# 4                                         6                         11.658497
#
#        application_type + loan_amnt  ...  credit_score - employment_length  \
# index                                ...
# 0                       1161.830205  ...                        672.016083
# 1                       2257.465815  ...                        658.240313
# 2                       2182.137002  ...                        693.277694
# 3                        520.284912  ...                        724.138779
# 4                       2303.349549  ...                        692.368991
#
#        credit_score - interest_rate  credit_score - loan_amnt  \
# index
# 0                        668.910721               -479.814122
# 1                        654.044114              -1589.225502
# 2                        694.969921              -1478.859308
# 3                        724.182275                210.853868
# 4                        686.710494              -1604.980558
#
#        credit_score - term  employment_length - interest_rate  \
# index
# 0               679.016083                          -3.105362
# 1               663.240313                          -4.196200
# 2               700.277694                           1.692228
# 3               728.138779                           0.043496
# 4               695.368991                          -5.658497
#
#        employment_length - loan_amnt  employment_length - term  \
# index
# 0                       -1151.830205                         7
# 1                       -2247.465815                         5
# 2                       -2172.137002                         7
# 3                        -513.284912                         4
# 4                       -2297.349549                         3
#
#        interest_rate - loan_amnt  interest_rate - term  loan_amnt - term
# index
# 0                   -1148.724843             10.105362       1158.830205
# 1                   -2243.269615              9.196200       2252.465815
# 2                   -2173.829229              5.307772       2179.137002
# 3                    -513.328407              3.956504        517.284912
# 4                   -2291.691052              8.658497       2300.349549
#
# [5 rows x 81 columns]

# %%
test_pkl = feature_matrix.copy()

# %%
test_pkl['id'] = train_pk2['id']

# %%
test_pkl.shape
# Out:
# (26900, 82)

# %%
test_pkl.isnull().sum()[test_pkl.isnull().sum() > 0]
# Out:
# application_type / employment_length    2000
# employment_length / application_type    2000
# dtype: int64

# %%
test_pkl.fillna(0, inplace=True)

# %%
test_pkl.isnull().sum()[test_pkl.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
test_pkl.to_pickle('test.pk2')
