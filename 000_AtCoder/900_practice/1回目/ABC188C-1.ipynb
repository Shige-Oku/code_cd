# %%
N = int(input())
# Out:
#  9

# %%
An = list(map(int, input().split()))
# Out:
#  727046556 647679139 180070638 844425894 496284099 677156830 311632592 506745591 196891730 611909551 212175727 17463413 771095849 273958922 512350243 901451093 155774255 987439075 499454628 873650848 229414644 351049239 106764529 150859700 481908221 888239237 501192315 885575396 547960322 33152828 383285747 602705658 895712770 345815732 835874650 898500447 451478586 419855874 495676117 813323012 938618189 945703113 382183653 126606333 393248783 399612817 453958954 346324909 5262353 437280777 960363177 848677315 266615165 392638351 724786612 854335045 636622526 363682178 287550568 382726393 859937046 721370289 532433281 305282029 378288751 596871335 898281156 20094848 761643658 490368906 15741159 759321877 711206796 996522497 430136601 710523174 817654844 528939729 659622987 131899658 210026566 478374536 801308505 142994563 273683074 658081201 126818457 258265861 789713173 598474924 136217166 978172176 797256627 807145676 107960266 406049031 292781881 860782516 447692468 396652106 551
# ...

# %%
s = min(max(An[:2**(N-1)]), max(An[2**(N-1):]))

# %%
print(An.index(s)+1)
# Out:
# 74

# %%
for ans, A in enumerate(An, 1):
    if A == s:
        print(ans)
        break
# Out:
# 74

# %%
ma1, ma2 = max(An[:N]), max(An[N:])

# %%
ma1, ma2
# Out:
# (13, 16)

# %%
s
# Out:
# 844425894

# %%
An[73]
# Out:
# 996522497

# %%
len(An)
# Out:
# 512
